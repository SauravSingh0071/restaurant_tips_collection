# %%
# import necessary libaries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm

# %%
# load a sample dataset from seaborn

data = sns.load_dataset('tips')

# %%
# display the dataset
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# it show total number of row & column
data.shape
# Out:
# (244, 7)

# %%
# it shows the count, mean, std, min, 25%, 50%, 75% and max values from the dataset
data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# it show True where error is occur otherwise give False
data.isnull()
# Out:
#      total_bill    tip    sex  smoker    day   time   size
# 0         False  False  False   False  False  False  False
# 1         False  False  False   False  False  False  False
# 2         False  False  False   False  False  False  False
# 3         False  False  False   False  False  False  False
# 4         False  False  False   False  False  False  False
# ..          ...    ...    ...     ...    ...    ...    ...
# 239       False  False  False   False  False  False  False
# 240       False  False  False   False  False  False  False
# 241       False  False  False   False  False  False  False
# 242       False  False  False   False  False  False  False
# 243       False  False  False   False  False  False  False
#
# [244 rows x 7 columns]

# %%
# it count the error in the column
data.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
# shows first 5 data from dataset
data.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# shows last 5 data from dataset
data.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
# shows random data from dataset
data.sample(6)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 68        20.23  2.01    Male     No  Sat  Dinner     2
# 212       48.33  9.00    Male     No  Sat  Dinner     4
# 225       16.27  2.50  Female    Yes  Fri   Lunch     2
# 218        7.74  1.44    Male    Yes  Sat  Dinner     2
# 42        13.94  3.06    Male     No  Sun  Dinner     2
# 94        22.75  3.25  Female     No  Fri  Dinner     2

# %%
# Descriptive Statistics

print("\n--- Descriptive Statistics ---")
mean_tip = data['tip'].mean()
median_tip = data['tip'].median()
mode_tip = data['tip'].mode()[0]
std_tip = data['tip'].std()


print(f"Mean: {mean_tip}")
print(f"Median: {median_tip}")
print(f"Mode: {mode_tip}")
print(f"Standard Deviation: {std_tip}")
# Out:
# --- Descriptive Statistics ---
# Mean: 2.99827868852459
# Median: 2.9
# Mode: 2.0
# Standard Deviation: 1.3836381890011826

# %%
# Load the data into a DataFrame
df = pd.DataFrame(data)

# Display the first few rows to inspect the original data
print("Original Data :-")
print(df.head())

# Create mapping dictionaries for each of the columns
sex_mapping = {
    'Female': 1,
    'Male': 2
}

smoker_mapping = {
    'No': 0,
    'Yes': 1
}

day_mapping = {
    'Sun': 7,
    'Mon': 1,
    'Tue': 2,
    'Wed': 3,
    'Thur': 4,
    'Fri': 5,
    'Sat': 6
}

time_mapping = {
    'Dinner': 1,
    'Lunch': 2
}

# Apply the mappings using map() for each column
df['sex'] = df['sex'].map(sex_mapping)
df['smoker'] = df['smoker'].map(smoker_mapping)
df['day'] = df['day'].map(day_mapping)
df['time'] = df['time'].map(time_mapping)

# Display the updated DataFrame to verify the changes
print("\nUpdated Data with Numeric Columns :-")
print(df.head())
# Out:
# Original Data :-
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
#
# Updated Data with Numeric Columns :-
#    total_bill   tip sex smoker day time  size
# 0       16.99  1.01   1      0   7    1     2
# 1       10.34  1.66   2      0   7    1     3
# 2       21.01  3.50   2      0   7    1     3
# 3       23.68  3.31   2      0   7    1     2
# 4       24.59  3.61   1      0   7    1     4

# %%
# Load the data into a DataFrame
df = pd.DataFrame(data)

# Create mapping dictionaries for each of the columns
sex_mapping = {
    'Female': 1,
    'Male': 2
}

smoker_mapping = {
    'No': 0,
    'Yes': 1
}

day_mapping = {
    'Sun': 7,
    'Mon': 1,
    'Tue': 2,
    'Wed': 3,
    'Thur': 4,
    'Fri': 5,
    'Sat': 6
}

time_mapping = {
    'Dinner': 1,
    'Lunch': 2
}

# Apply the mappings using map() for each column
df['sex'] = df['sex'].map(sex_mapping)
df['smoker'] = df['smoker'].map(smoker_mapping)
df['day'] = df['day'].map(day_mapping)
df['time'] = df['time'].map(time_mapping)

# Display all dataset with changes
print("\nFull Data With Changes :-")
# print(df)

# Display dataset in range(Start: End)
print(df.iloc[2:10])
# Out:
# Full Data With Changes :-
#    total_bill   tip sex smoker day time  size
# 2       21.01  3.50   2      0   7    1     3
# 3       23.68  3.31   2      0   7    1     2
# 4       24.59  3.61   1      0   7    1     4
# 5       25.29  4.71   2      0   7    1     4
# 6        8.77  2.00   2      0   7    1     2
# 7       26.88  3.12   2      0   7    1     4
# 8       15.04  1.96   2      0   7    1     2
# 9       14.78  3.23   2      0   7    1     2
